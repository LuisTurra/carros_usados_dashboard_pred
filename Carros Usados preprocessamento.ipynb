# %%
import mysql.connector
import pandas as pd

# %%
conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='lhtr23@#2223L',
    database='carros_usado',
)

# %%
query = "SELECT * FROM used_car_listings;"
df = pd.read_sql(query, conn)
# Out:
# C:\Users\Microsoft\AppData\Local\Temp\ipykernel_10528\521062435.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %%
df
# Out:
#       listing_id                vin       make     model  year      trim  \
# 0              1  9M6LF68V634LY2252      Tesla   Model 3  2019      None
# 1              2  1S0ZCY536BSCY2864     Nissan     Rogue  2024        LT
# 2              3  YFB625BN0RTMZ5590    Hyundai       i20  2018       XLE
# 3              4  CPMZ4RFN5WYL37096        Kia  Sportage  2023        EX
# 4              5  4PJZG3MV6D9365673        Kia    Seltos  2020     Trend
# ...          ...                ...        ...       ...   ...       ...
# 2063        2064  06B83BVF8F2W81547      Skoda    Kushaq  2023     Sport
# 2064        2065  4P7083L79MBVK5696   Mahindra   Scorpio  2016       XSE
# 2065        2066  5RERFW1M7B00A4061       Audi        A6  2018        EX
# 2066        2067  DJB6DBAS5UNNX0757      Skoda    Kushaq  2021        LX
# 2067        2068  8BUANECR64R9L0827  Chevrolet    Malibu  2024  Platinum
#
#       body_type fuel_type transmission  mileage    price  condition  \
# ...

# %%
df
# Out:
#       listing_id                vin       make     model  year      trim  \
# 0              1  9M6LF68V634LY2252      Tesla   Model 3  2019      None
# 1              2  1S0ZCY536BSCY2864     Nissan     Rogue  2024        LT
# 2              3  YFB625BN0RTMZ5590    Hyundai       i20  2018       XLE
# 3              4  CPMZ4RFN5WYL37096        Kia  Sportage  2023        EX
# 4              5  4PJZG3MV6D9365673        Kia    Seltos  2020     Trend
# ...          ...                ...        ...       ...   ...       ...
# 2063        2064  06B83BVF8F2W81547      Skoda    Kushaq  2023     Sport
# 2064        2065  4P7083L79MBVK5696   Mahindra   Scorpio  2016       XSE
# 2065        2066  5RERFW1M7B00A4061       Audi        A6  2018        EX
# 2066        2067  DJB6DBAS5UNNX0757      Skoda    Kushaq  2021        LX
# 2067        2068  8BUANECR64R9L0827  Chevrolet    Malibu  2024  Platinum
#
#       body_type fuel_type transmission  mileage    price  condition  \
# ...

# %%
df["price"] = df["price"].astype(int)

# %%
df
# Out:
#       listing_id                vin       make     model  year      trim  \
# 0              1  9M6LF68V634LY2252      Tesla   Model 3  2019      None
# 1              2  1S0ZCY536BSCY2864     Nissan     Rogue  2024        LT
# 2              3  YFB625BN0RTMZ5590    Hyundai       i20  2018       XLE
# 3              4  CPMZ4RFN5WYL37096        Kia  Sportage  2023        EX
# 4              5  4PJZG3MV6D9365673        Kia    Seltos  2020     Trend
# ...          ...                ...        ...       ...   ...       ...
# 2063        2064  06B83BVF8F2W81547      Skoda    Kushaq  2023     Sport
# 2064        2065  4P7083L79MBVK5696   Mahindra   Scorpio  2016       XSE
# 2065        2066  5RERFW1M7B00A4061       Audi        A6  2018        EX
# 2066        2067  DJB6DBAS5UNNX0757      Skoda    Kushaq  2021        LX
# 2067        2068  8BUANECR64R9L0827  Chevrolet    Malibu  2024  Platinum
#
#       body_type fuel_type transmission  mileage  price  condition  \
# ...

# %%
df["features"] = df["features"].str.split(", ")

# %%
features_encoded = pd.get_dummies(df["features"].explode()).groupby(level=0).max()

# %%
df_final = df.drop(columns=["features"]).join(features_encoded)

# %%
pd.set_option('display.max_columns', None)
df_final
# Out:
#       listing_id       make     model  year      trim  body_type fuel_type  \
# 0              1      Tesla   Model 3  2019      None      Coupe  Electric
# 1              2     Nissan     Rogue  2024        LT      Sedan    Hybrid
# 2              3    Hyundai       i20  2018       XLE  Crossover    Petrol
# 3              4        Kia  Sportage  2023        EX  Hatchback    Diesel
# 4              5        Kia    Seltos  2020     Trend     Pickup    Diesel
# ...          ...        ...       ...   ...       ...        ...       ...
# 2063        2064      Skoda    Kushaq  2023     Sport     Pickup    Petrol
# 2064        2065   Mahindra   Scorpio  2016       XSE        SUV    Diesel
# 2065        2066       Audi        A6  2018        EX  Hatchback    Diesel
# 2066        2067      Skoda    Kushaq  2021        LX        MPV    Petrol
# 2067        2068  Chevrolet    Malibu  2024  Platinum      Sedan    Diesel
#
#      transmission  mileage  price  condition          seller_type  \
# ...

# %%
df_final = df_final.drop("vin", axis=1)

# %%
df_final

# %%
df_final.to_csv("Carros Usados.csv", index=False)
